# %%
import jieba
import jieba.analyse
import pandas as pd
import numpy
from collections import Counter

# %%
orgdata = pd.read_csv('LawTech_0727_Pandas.csv')

# %%
orgdata.head()
# Out:
#    Unnamed: 0                              title       date             judge  \
# 0           0  最高法院 108 年度 台上 字第 2708 號刑事判決（15K）  109.09.30                詐欺
# 1           1  最高法院 109 年度 台上 字第 1719 號刑事判決（29K）  109.04.15         違反證券交易法等罪
# 2           2  最高法院 108 年度 台上 字第 4056 號刑事判決（29K）  109.04.15         違反證券交易法等罪
# 3           3    最高法院 108 年度 台上 字第 16 號刑事判決（37K）  109.01.16         違反證券交易法等罪
# 4           4     最高法院 109 年度 台抗 字第 46 號刑事裁定（5K）  109.01.09  違反證券交易法等罪不服再執行羈押
#
#                                              content  \
# 0  最高法院刑事判決　　　　　　　　　 108年度台上字第2708號\n上　訴　人　林鶴爵\n\...
# 1  最高法院刑事判決　　　　　　　　　 108年度台上字第4056號\n　　　　　　　　　　　　...
# 2  最高法院刑事判決　　　　　　　　　 108年度台上字第4056號\n　　　　　　　　　　　　...
# 3  最高法院刑事判決　　　　　　　　　　 108年度台上字第16號\n上　訴　人　臺灣高等檢察署...
# 4  最高法院刑事裁定　　　　　　　　　　 109年度台抗字第46號\n抗　告　人　許金龍\n\n...
#
#                                                 link
# 0  https://law.judicial.gov.tw/FJUD/data.aspx?ro=...
# 1  https://law.judicial.gov.tw/FJUD/data.aspx?ro=...
# 2  https://law.judicial.gov.tw/FJUD/data.aspx?ro=...
# 3  https://law.judicial.gov.tw/FJUD/data.aspx?ro=...
# 4  https://law.judicial.gov.tw/FJUD/data.aspx?ro=...

# %%
documents = ['我是東吳大學巨量資料管理學院蔡芸琤老師']
# 精確模式
for sentence in documents:
    seg_list = jieba.cut(sentence)
    print('/'.join(seg_list))
# Out:
# 我/是/東吳大學/巨量資料管理學院/蔡芸琤/老師

# %%
jieba.load_userdict('./userdict.txt')

for sentence in documents:
    seg_list = jieba.cut(sentence)
    print('/'.join(seg_list))
# Out:
# 我/是/東吳大學/巨量資料管理學院/蔡芸琤/老師

# %%
orgdata['seg'] = ""
orgdata.head()
# Out:
#    Unnamed: 0                              title       date             judge  \
# 0           0  最高法院 108 年度 台上 字第 2708 號刑事判決（15K）  109.09.30                詐欺
# 1           1  最高法院 109 年度 台上 字第 1719 號刑事判決（29K）  109.04.15         違反證券交易法等罪
# 2           2  最高法院 108 年度 台上 字第 4056 號刑事判決（29K）  109.04.15         違反證券交易法等罪
# 3           3    最高法院 108 年度 台上 字第 16 號刑事判決（37K）  109.01.16         違反證券交易法等罪
# 4           4     最高法院 109 年度 台抗 字第 46 號刑事裁定（5K）  109.01.09  違反證券交易法等罪不服再執行羈押
#
#                                              content  \
# 0  最高法院刑事判決　　　　　　　　　 108年度台上字第2708號\n上　訴　人　林鶴爵\n\...
# 1  最高法院刑事判決　　　　　　　　　 108年度台上字第4056號\n　　　　　　　　　　　　...
# 2  最高法院刑事判決　　　　　　　　　 108年度台上字第4056號\n　　　　　　　　　　　　...
# 3  最高法院刑事判決　　　　　　　　　　 108年度台上字第16號\n上　訴　人　臺灣高等檢察署...
# 4  最高法院刑事裁定　　　　　　　　　　 109年度台抗字第46號\n抗　告　人　許金龍\n\n...
#
#                                                 link seg
# 0  https://law.judicial.gov.tw/FJUD/data.aspx?ro=...
# 1  https://law.judicial.gov.tw/FJUD/data.aspx?ro=...
# 2  https://law.judicial.gov.tw/FJUD/data.aspx?ro=...
# 3  https://law.judicial.gov.tw/FJUD/data.aspx?ro=...
# 4  https://law.judicial.gov.tw/FJUD/data.aspx?ro=...

# %%
jieba.analyse.set_stop_words('stopwords.txt')
index = 0
for documents in orgdata['content']:
    seg_list = jieba.analyse.extract_tags(documents, 150)
    #seg_list = jieba.lcut(documents)
    orgdata['seg'].iloc[index] = seg_list
    index += 1
# Out:
# d:\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
orgdata['seg']
# Out:
# 0     [上訴, 原判, 沒收, 理由, 證據, 明細, 德育, 公司, 認定, 指摘, 本案, 意...
# 1     [原判, 編號, 附表, 王宗立, 專案, 交易法, 上訴, 證券, 被害人, 所示, 修正...
# 2     [原判, 編號, 附表, 王宗立, 專案, 交易法, 上訴, 證券, 被害人, 所示, 修正...
# 3     [原判, 許金龍, 公司, 條第, 105, 事實, 犯罪, 交易法, 證券, 謝東波, 財...
# 4     [抗告, 羈押, 具保, 條第, 執行, 退保, 刑事, 108, 原審, 12, 訴訟法,...
# 5     [財務, 上訴, 報告, 勤美, 公司, 下稱, 97, 投資人, 95, 萬元, 98, ...
# 6     [條第, 羈押, 具保, 抗告, 被告, 裁定, 停止, 同法, 171, 108, 億元,...
# 7     [證券, 原判, 條第, 被害人, 被告, 交易法, 價證券, 有價, 17, 未上市, 偽...
# 8     [95, 上訴, 財報, 仕欽, 條第, 附表, 公司, 損害, 董事, 賠償, 20, 監...
# 9     [YUR, 原判, 證券, 條第, 科風, 財務, 說明, POWER, 公司, 認定, 報...
# 10    [銀行, 博達, 上訴, 公司, 附表, 賠償, 永豐, 財務, 報告, 93, 92, 不...
# 11    [上訴, 證據, 原判, 影響, 證券, 修正, 投資, 消息, 理由, 交易法, 規定, ...
# 12    [上訴, 揚崴, 原判, 專利權, 化油器, 張龍憲, 公司, 證券, 王明, 張龍, 理由...
# 13    [抗告, 出境, 裁定, 執行, 審判, 限制, 刑事, 第一, 出海, 檢察官, 交易法,...
# 14    [景天, 上訴, 原判, 增資, 判決, 公司, 李易翰, 理由, 違反, 證券, 顧問, ...
# 15    [鑑定, EUPA, 吳燦坤, 掛牌, 公司, 檢察官, 上訴, 意見, 永生, 燦坤, 美...
# 16    [財務, 報告, 原判, 公司, 重大, 交易, 鑑定, 規定, 認定, 事項, 本法, 上...
# 17    [原判, 福建, 盧寶琴, 證券, 負責人, 公司, 記載, 資金, 規定, 政忠, 起訴,...
# 18    [上訴, 理由, 一卡, 原判, 判決, 資料, 認定, 證據, 事實, 第三, 違法, 張...
# 19    [原判, 蔡姵淳, 志瑜, 育新, 公司, 錦享, 鄭晴心, 巨星, 理由, 銷售, 上訴,...
# 20    [證券, 原判, 上訴, Fund, LP, 投資人, 交易法, Lydia, 判決, 股權...
# 21    [公司, 報告, 賠償, 久津, 上訴, 財務, 證券, 損害, 公開, 郭保富, 請求, ...
# 22    [上訴, 東森國際, 公司, 財務, 報告, 查核, 投資人, 損害, 嘉食化, 交易, 王...
# 23    [林國仁, 珍通, 上訴, 呂德茂, 原判, 許金村, 調查, 認定, 證據, 適用, 被告...
# 24    [上訴, 證據, 原判, 違法, 調查, 理由, 判決, 公司, 意旨, 認定, 原審, 第...
# 25    [抗告, 珍通, 公司, 判決, 銀行, 淑珍, 認定, 萬元, 證據, 增資, 林貞祥, ...
# 26    [上訴, 理由, 原判, 判決, 朱耕廷, 審上訴, 第一, 違背, 第三, 部分, 檢察官...
# 27    [上訴, 原判, 淑珍, 公司, 萬元, 二千五百, 林國仁, 理由, 證據, 認定, 增資...
# 28    [發行, 證券, 公司, 被告, 博微, 交易法, 上訴, 申報, 原判, 判決, 公開, ...
# 29    [上訴, 規定, 原判, 交易法, 保證, 虛偽, 證券, 記載, 背書, 瑩寶, 財務, ...
# 30    [上訴, 證券, 原判, 判決, 環球, 投資, 起訴, 交易法, 理由, 公司, 企業, ...
# 31    [原判, 公司, 上訴, 不實, 認定, 違法, 決第, 犯罪, 連續, 負責人, 理由, ...
# 32    [上訴, 損害, 賠償, 公司, 九十年, 八十九年, 不實, 財務, 年度, 請求, 金額...
# 33    [上訴, 偽造, 施政, 原判, 調查, 證據, 銀行, 認定, 保證, 林永輝, 荷蘭, ...
# 34    [公司, 友昱, 原判, 捷通, 交易, 認定, 偵字, 第一, 第二, 張子, CHAMP...
# 35    [上訴, 蕃薯, 上櫃, 簡麗蓉, 購買, 附表, 公司股票, 公司, 原判, 侯銀月, 簡...
# 36    [志豪, 原判, 李仁魯, 上訴, 瑞傳, 編號, 公司, 證據, 寰生, 調查, 違法, ...
# 37    [上訴, 正仁, 損害, 股價, 操縱, 因果, 賠償, 順大裕, 請求, 判決, 破產, ...
# 38    [上訴, 起訴, 證券, 原判, 判決, 第三, 審上訴, 結果, 證據, 判斷, 市場, ...
# 39    [上訴, 損害, 順大裕, 違約, 請求, 正仁, 民事, 賠償, 公司股票, 交割, 不實...
# 40    [一卡, 上訴, 證券, 原判, 價證券, 適用, 規定, 第一百七, 理由, 交易法, 認...
# 41    [原判, 公司, CCMP, 100, 證據, 九十年, 說明, 藍芽, 理由, 上訴, 事...
# 42    [原判, 證券, 犯罪, 交易法, 順大裕, 第一, 規定, 行為, 股票, 帳戶, 第一百...
# 43    [支票, 偽造, 上訴, 原判, 價證券, 財物, 簽發, 交付, 行使, 附表, 判決, ...
# Name: seg, dtype: object

# %%
date_split = orgdata['date'].iloc[0].split('.')

# %%
date_split[0]
# Out:
# '109'

# %%
orgdata['year'] = ""
index = 0
for documents in orgdata['date']:
    date_split = documents.split('.')
    orgdata['year'].iloc[index] = date_split[0]
    index += 1

# %%
orgdata.head()
# Out:
#    Unnamed: 0                              title       date             judge  \
# 0           0  最高法院 108 年度 台上 字第 2708 號刑事判決（15K）  109.09.30                詐欺
# 1           1  最高法院 109 年度 台上 字第 1719 號刑事判決（29K）  109.04.15         違反證券交易法等罪
# 2           2  最高法院 108 年度 台上 字第 4056 號刑事判決（29K）  109.04.15         違反證券交易法等罪
# 3           3    最高法院 108 年度 台上 字第 16 號刑事判決（37K）  109.01.16         違反證券交易法等罪
# 4           4     最高法院 109 年度 台抗 字第 46 號刑事裁定（5K）  109.01.09  違反證券交易法等罪不服再執行羈押
#
#                                              content  \
# 0  最高法院刑事判決　　　　　　　　　 108年度台上字第2708號\n上　訴　人　林鶴爵\n\...
# 1  最高法院刑事判決　　　　　　　　　 108年度台上字第4056號\n　　　　　　　　　　　　...
# 2  最高法院刑事判決　　　　　　　　　 108年度台上字第4056號\n　　　　　　　　　　　　...
# 3  最高法院刑事判決　　　　　　　　　　 108年度台上字第16號\n上　訴　人　臺灣高等檢察署...
# 4  最高法院刑事裁定　　　　　　　　　　 109年度台抗字第46號\n抗　告　人　許金龍\n\n...
#
#                                                 link  \
# 0  https://law.judicial.gov.tw/FJUD/data.aspx?ro=...
# 1  https://law.judicial.gov.tw/FJUD/data.aspx?ro=...
# 2  https://law.judicial.gov.tw/FJUD/data.aspx?ro=...
# 3  https://law.judicial.gov.tw/FJUD/data.aspx?ro=...
# 4  https://law.judicial.gov.tw/FJUD/data.aspx?ro=...
#
#                                                  seg year
# 0  [上訴, 原判, 沒收, 理由, 證據, 明細, 德育, 公司, 認定, 指摘, 本案, 意...  109
# 1  [原判, 編號, 附表, 王宗立, 專案, 交易法, 上訴, 證券, 被害人, 所示, 修正...  109
# 2  [原判, 編號, 附表, 王宗立, 專案, 交易法, 上訴, 證券, 被害人, 所示, 修正...  109
# 3  [原判, 許金龍, 公司, 條第, 105, 事實, 犯罪, 交易法, 證券, 謝東波, 財...  109
# 4  [抗告, 羈押, 具保, 條第, 執行, 退保, 刑事, 108, 原審, 12, 訴訟法,...  109

# %%
orgdata.to_csv("LawTech_0727_TextMining.csv", index=False)

# %%
Counter(orgdata['year']).keys()
# Out:
# dict_keys(['109', '108', '107', '106', '105', '104', '103', '102', '101', '100', '99', '98', '96', '85'])

# %%
words = list(orgdata['judge'])
show_key = pd.DataFrame(Counter(words).keys())
show_values = pd.DataFrame(Counter(words).values())

# %%
df = [show_key, show_values]

# %%
result = pd.concat(df, axis=1)
result.columns = ['judge', 'freguency']
result
# Out:
#                  judge  freguency
# 0                   詐欺          1
# 1            違反證券交易法等罪         12
# 2     違反證券交易法等罪不服再執行羈押          1
# 3               請求損害賠償          4
# 4    違反證券交易法等罪聲請具保停止羈押          1
# 5           請求侵權行為損害賠償          1
# 6              違反證券交易法         16
# 7      違反證券交易法等罪限制出境出海          1
# 8          請求侵權行為損害賠償等          1
# 9   違反證券交易法等罪聲請再審及停止執行          1
# 10             違反商業會計法          1
# 11                損害賠償          2
# 12              偽造文書等罪          1
# 13              偽造有價證券          1

# %%
import plotly.express as px
import pandas as pd

px.bar(result, x='judge', y='freguency', title='judge term from 85 to 109')
# Out:
# <div>                            <div id="72f95fbd-2e57-4131-864e-81050db2363e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("72f95fbd-2e57-4131-864e-81050db2363e")) {                    Plotly.newPlot(                        "72f95fbd-2e57-4131-864e-81050db2363e",                        [{"alignmentgroup":"True","hovertemplate":"judge=%{x}<br>freguency=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","type":"bar","x":["\u8a50\u6b3a","\u9055\u53cd\u8b49\u5238\u4ea4\u6613\u6cd5\u7b49\u7f6a","\u9055\u53cd\u8b49\u5238\u4ea4\u6613\u6cd5\u7b49\u7f6a\u4e0d\u670d\u518d\u57f7\u884c\u7f88\u62bc","\u8acb\u6c42\u640d\u5bb3\u8ce0\u511f","\u9055\u53cd\u8b49\u5238\u4ea4\u6613\u6cd5\u7b49\u7f6a\u8072\u8acb\u5177\u4fdd\u505c\u6b62\u7f88\u62bc","\u8acb\u6c42\u4fb5\u6b0a\u884c\u70ba\u640d\u5bb3\u8ce0\u511f","\u9055\u53cd\u8b49\u5238\u4ea4\u6613\u6cd5","\u9055\u53cd\u8b49\u5238\u4ea4\u6613\u6cd5\u7b49\u7f6a\u9650\u5236\u51fa\u5883\u51fa\u6d77","\u8acb\u6c42\u4fb5\u6b0a\u884c\u70ba\u640d\u5bb3\u8ce0\u511f\u7b49","\u9055\u53cd\u8b49\u5238\u4ea4\u6613\u6cd5\u7b49\u7f6a\u8072\u8acb\u518d\u5be9\u53ca\u505c\u6b62\u57f7\u884c","\u9055\u53cd\u5546\u696d\u6703\u8a08\u6cd5","\u640d\u5bb3\u8ce0\u511f","\u507d\u9020\u6587\u66f8\u7b49\u7f6a","\u507d\u9020\u6709\u50f9\u8b49\u5238"],"xaxis":"x","y":[1,12,1,4,1,1,16,1,1,1,1,2,1,1],"yaxis":"y"}],                        {"barmode":"relative","legend":{"tracegroupgap":0},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.55555 ...

# %%
show_sub = orgdata['judge']=='違反證券交易法'
subdata = orgdata[show_sub]
subdata
# Out:
#     Unnamed: 0                              title       date    judge  \
# 9            9   最高法院 106 年度 台上 字第 278 號刑事判決（12K）  106.09.28  違反證券交易法
# 11          11    最高法院 106 年度 台上 字第 86 號刑事判決（33K）  106.05.31  違反證券交易法
# 12          12  最高法院 106 年度 台上 字第 1115 號刑事判決（13K）  106.05.04  違反證券交易法
# 15          15  最高法院 105 年度 台上 字第 2144 號刑事判決（20K）  105.08.23  違反證券交易法
# 16          16  最高法院 105 年度 台上 字第 1948 號刑事判決（14K）  105.08.04  違反證券交易法
# 18          18   最高法院 104 年度 台上 字第 3516 號刑事判決（5K）  104.11.19  違反證券交易法
# 20          20  最高法院 104 年度 台上 字第 3041 號刑事判決（25K）  104.10.08  違反證券交易法
# 23          23    最高法院 104 年度 台非 字第 107 號刑事判決（8K）  104.04.16  違反證券交易法
# 24          24  最高法院 104 年度 台上 字第 1060 號刑事判決（13K）  104.04.16  違反證券交易法
# 29          29    最高法院 103 年度 台上 字第 196 號刑事判決（7K）  103.01.16  違反證券交易法
# 30          30    最高法院 103 年度 台上 字第 125 號刑事判決（5K）  103.01.09  違反證券交易法
# 35          35  最高法院 100 年度 台上 字第 2611 號刑事判決（21K）  100.05.19  違反證券交易法
# 36          36   最高法院 100 年度 台上 字第 995 號刑事判決（24K）  100.03.03  違反證券交易法
# 38          38    最高法院 99 年度 台上 字第 7323 號刑事判決（6K）   99.11.25  違反證券交易法
# 40          40   最高法院 99 年度 台上 字第 3110 號刑事判決（11K）   99.05.20  違反證券交易法
# 41          41    最高法院 98 年度 台上 字第 6896 號刑事判決（9K）   98.11.19  違反證券交易法
#
#                                               content  \
# 9   最高法院刑事判決　　　　　　　　　　106年度台上字第278號\n上　訴　人　臺灣高等法院檢...
# 11  最高法院刑事判決　　　　　　　　一○六年度台上字第八六號\n上　訴　人　葉禾庠（原名葉健和）...
# 12  最高法院刑事判決　　　　　　一○六年度台上字第一一一五號\n上　訴　人　黃文賢\n選任辯護人...
# 15  最高法院刑事判決　　　　　　一○五年度台上字第二一四四號\n上　訴　人　台灣高等法院檢察署檢...
# 16  最高法院刑事判決　　　　　　一○五年度台上字第一九四八號\n上　訴　人　郭麗美\n選任辯護人...
# 18  最高法院刑事判決　　　　　　一○四年度台上字第三五一六號\n上　訴　人　陳俟杰\n上列上訴人...
# 20  最高法院刑事判決　　　　　　一○四年度台上字第三○四一號\n上　訴　人　台灣高等法院檢察署檢...
# 23  最高法院刑事判決　　　　　　　一○四年度台非字第一○七號\n上　訴　人　最高法院檢察署檢察總...
# 24  最高法院刑事判決　　　　　　一○四年度台上字第一○六○號\n上　訴　人　張伊犂\n選任辯護人...
# 29  最高法院刑事判決　　　　　　　一○三年度台上字第一九六號\n上　訴　人　唐濟群\n選任辯護人...
# 30  最高法院刑事判決　　　　　　　一○三年度台上字第一二五號\n上　訴　人　蔡昌佑\n選任辯護人...
# 35  最高法院刑事判決　　　　　　一○○年度台上字第二六一一號\n上　訴　人　吳晉維原名吳振彰.\...
# 36  最高法院刑事判決　　　　　　　一○○年度台上字第九九五號\n上　訴　人　台灣高等法院高雄分院...
# 38  最高法院刑事判決　　　　　　九十九年度台上字第七三二三號\n上　訴　人　李良奇\n選任辯護人...
# 40  最高法院刑事判決　　　　　　九十九年度台上字第三一一０號\n上　訴　人　甲○○\n選任辯護人...
# 41  最高法院刑事判決　　　　　　九十八年度台上字第六八九六號\n上　訴　人　丙○○\n選任辯護人...
#
#                                                  link  \
# 9   https://law.judicial.gov.tw/FJUD/data.aspx?ro=...
# 11  https://law.judicial.gov.tw/FJUD/data.aspx?ro=...
# 12  https://law.judicial.gov.tw/FJUD/data.aspx?ro=...
# 15  https://law.judicial.gov.tw/FJUD/data.aspx?ro=...
# 16  https://law.judicial.gov.tw/FJUD/data.aspx?ro=...
# 18  https://law.judicial.gov.tw/FJUD/data.aspx?ro=...
# 20  https://law.judicial.gov.tw/FJUD/data.aspx?ro=...
# 23  https://law.judicial.gov.tw/FJUD/data.aspx?ro=...
# 24  https://law.judicial.gov.tw/FJUD/data.aspx?ro=...
# 29  https://law.judicial.gov.tw/FJUD/data.aspx?ro=...
# 30  https://law.judicial.gov.tw/FJUD/data.aspx?ro=...
# 35  https://law.judicial.gov.tw/FJUD/data.aspx?ro=...
# 36  https://law.judicial.gov.tw/FJUD/data.aspx?ro=...
# 38  https://law.judicial.gov.tw/FJUD/data.aspx?ro=...
# 40  https://law.judicial.gov.tw/FJUD/data.aspx?ro=...
# 41  https://law.judicial.gov.tw/FJUD/data.aspx?ro=...
#
#                                                   seg year
# 9   [YUR, 原判, 證券, 條第, 科風, 財務, 說明, POWER, 公司, 認定, 報...  106
# 11  [上訴, 證據, 原判, 影響, 證券, 修正, 投資, 消息, 理由, 交易法, 規定, ...  106
# 12  [上訴, 揚崴, 原判, 專利權, 化油器, 張龍憲, 公司, 證券, 王明, 張龍, 理由...  106
# 15  [鑑定, EUPA, 吳燦坤, 掛牌, 公司, 檢察官, 上訴, 意見, 永生, 燦坤, 美...  105
# 16  [財務, 報告, 原判, 公司, 重大, 交易, 鑑定, 規定, 認定, 事項, 本法, 上...  105
# 18  [上訴, 理由, 一卡, 原判, 判決, 資料, 認定, 證據, 事實, 第三, 違法, 張...  104
# 20  [證券, 原判, 上訴, Fund, LP, 投資人, 交易法, Lydia, 判決, 股權...  104
# 23  [林國仁, 珍通, 上訴, 呂德茂, 原判, 許金村, 調查, 認定, 證據, 適用, 被告...  104
# 24  [上訴, 證據, 原判, 違法, 調查, 理由, 判決, 公司, 意旨, 認定, 原審, 第...  104
# 29  [上訴, 規定, 原判, 交易法, 保證, 虛偽, 證券, 記載, 背書, 瑩寶, 財務, ...  103
# 30  [上訴, 證券, 原判, 判決, 環球, 投資, 起訴, 交易法, 理由, 公司, 企業, ...  103
# 35  [上訴, 蕃薯, 上櫃, 簡麗蓉, 購買, 附表, 公司股票, 公司, 原判, 侯銀月, 簡...  100
# 36  [志豪, 原判, 李仁魯, 上訴, 瑞傳, 編號, 公司, 證據, 寰生, 調查, 違法, ...  100
# 38  [上訴, 起訴, 證券, 原判, 判決, 第三, 審上訴, 結果, 證據, 判斷, 市場, ...   99
# 40  [一卡, 上訴, 證券, 原判, 價證券, 適用, 規定, 第一百七, 理由, 交易法, 認...   99
# 41  [原判, 公司, CCMP, 100, 證據, 九十年, 說明, 藍芽, 理由, 上訴, 事...   98

# %%
type(subdata['seg'])
# Out:
# pandas.core.series.Series

# %%
subdata_seg_list = subdata['seg'].tolist()
type(subdata_seg_list)
# Out:
# list

# %%
subdata_seg_list
# Out:
# [['YUR',
#   '原判',
#   '證券',
#   '條第',
#   '科風',
#   '財務',
#   '說明',
#   'POWER',
#   '公司',
#   '認定',
#   '報告',
#   'Yuraku',
#   'Pte',
#   '發行',
#   'Ltd',
#   '指標',
#   '交易法',
#   '銷售',
#   '理由',
#   '交易',
#   '判決',
#   '責任',
#   '規定',
#   '家電廠',
#   '應收',
#   '帳款',
#   '事項',
#   '行為',
#   '刑事',
#   '青妙',
#   '100',
#   '98',
#   '銷貨',
#   '20',
#   '判斷',
#   'Powercom',
#   '決第',
#   '重大',
#   '部分',
#   '揭露',
#   '上訴',
#   '下稱',
#   '99',
#   '證據',
#   '對象',
#   '企業',
#   '影響',
#   '隱匿',
#   '內容',
#   '資訊',
#   '量性',
#   '例示',
#   '違反',
#   '15',
#   '171',
#   '發回',
#   '事實',
#   '申報',
#   '實罪',
#   '虛偽',
#   '記載',
#   '否則',
#   '17',
#   '仟元',
#   '社會',
#   '反詐',
#   '質性',
#   '檢視',
#   '行人',
#   '年度',
#   '大利',
#   '要件',
#   '法官',
#   '106',
#   '決關',
#   '財報',
#   '撤銷',
#   '會計',
#   '年間',
#   '歐倉',
#   '之銷',
#   '實際',
#   '認為',
#   '訴訟法',
#   '適用',
#   '客觀',
#   '呂姿儀',
#   '明函',
#   'SA',
#   '金額',
#   '作為',
#   '至於',
#   '業務',
#   '財務報',
#   '欺條款',
#   '投資人',
#   '學理',
#   '13',
#   '具備',
#   '原審',
#   '法院',
#   '本院',
#   '情事',
#   '指摘',
#   '高等法院',
#   '法令',
#   '收入',
#   '是否',
#   '大量出',
#   '援引',
#   '有人',
#   '科刑',
#   '檢察署',
#   '選任',
#   '辯護人',
#   '25',
#   '偵字',
#   '101',
#   '實欄',
#   '依證券',
#   '負責',
#   '216',
#   '設立',
#   '倉庫',
#   'FL',
#   '增銷貨',
#   '虛增',
#   '財務業務',
#   '發生',
#   '無罪',
#   '有關',
#   '適合',
#   '違背',
#   '職權',
#   '調查',
#   '證人',
#   '12',
#   '證密字',
#   '號函',
#   '10',
#   '轉投資',
#   'POWERI',
#   'II',
#   'III',
#   'SRL',
#   '模組',
#   '000',
#   '倒數',
#   '19',
#   'Yu'],
#  ['上訴',
#   '證據',
#   '原判',
#   '影響',
#   '證券',
#   '修正',
#   '投資',
#   '消息',
#   '理由',
#   '交易法',
#   '規定',
#   '認定',
#   '重大',
#   '勘驗',
#   '明確',
#   '說明',
#   'FDA',
#   '內線',
#   '價格',
#   '結果',
#   '第一百五十',
#   '公司',
#   '判決',
#   '犯罪',
#   '第一',
#   '違法',
#   '調查',
#   '判斷',
#   '意旨',
#   '原審',
#   '內容',
#   '發生',
#   '計算',
#   '七條',
#   '列印',
#   '交易',
#   '筆錄',
#   '公開',
#   '光碟',
#   '行為',
#   '股票',
#   '決定',
#   '留滯',
#   '投資人',
#   '時點',
#   '供述',
#   '資料',
#   '事實',
#   '二日',
#   '要件',
#   '所得',
#   '六月',
#   '第三',
#   '九十九年',
#   '公司股票',
#   '指摘',
#   '警告',
#   '十七年',
#   '法則',
#   '立法',
#   '具體',
#   '適用',
#   '辯護',
#   '營業',
#   '法院',
#   '辯護人',
#   '訴訟法',
#   '違背',
#   '之優',
#   '機率',
#   '實際',
#   '確定',
#   '之一',
#   '刑事',
#   '明力',
#   '審上訴',
#   '本件',
#   '傳聞',
#   '相關',
#   '偵訊',
#   '並未',
#   '資訊',
#   '獲悉',
#   '買賣',
#   '買入',
#   '條文',
#   '辦法',
#   '帳戶',
#   '股價',
#   '賣出',
#   '情形',
#   '程序',
#   '法官',
#   '及其',
#   '所指',
#   '能力',
#   '下稱',
#   '性質',
#   '該次',
#   '適法',
#   '構成',
#   '綜合',
#   '差額',
#   '知悉',
#   '云云',
#   '名下',
#   '第一百七',
#   '持有',
#   '四月',
#   '依據',
#   '違反',
#   '作為',
#   '並無',
#   '審判期',
#   '採證',
#   '上開',
#   '職權',
#   '發行',
#   '基準',
#   '他人',
#   '其他',
#   '援引',
#   '如何',
#   '第二',
#   '通知',
#   '公布',
#   '十一',
#   '附件',
#   '程度',
#   '部分',
#   '禁止',
#   '訴訟',
#   '審判',
#   '踐行',
#   '偵訊錄',
#   '影錄音',
#   'Import',
#   '參照',
#   '名義買',
#   '市場',
#   '正當',
#   '參酌',
#   '變化',
#   '賠償',
#   '瑕疵',
#   '合法',
#   '依法',
#   '法律',
#   '成立',
#   '二月'],
#  ['上訴',
#   '揚崴',
#   '原判',
#   '專利權',
#   '化油器',
#   '張龍憲',
#   '公司',
#   '證券',
#   '王明',
#   '張龍',
#   '理由',
#   '證據',
#   '專利',
#   '認定',
#   '萬元',
#   '量產',
#   '財務',
#   '調查',
#   '交易法',
#   '投資',
#   '錯誤',
#   '第三',
#   '違法',
#   '八十九年',
#   '年度',
#   '云云',
#   '八十七年',
#   '審上訴',
#   '資料',
#   '說明',
#   '盈餘為',
#   '取得',
#   '意旨',
#   '判決',
#   '影響',
#   '市場',
#   '經營',
#   '預估',
#   '萬餘元',
#   '一之',
#   '發行',
#   '支票',
#   '刑事',
#   '第一',
#   '訴訟法',
#   '法則',
#   '規定',
#   '實審',
#   '採信',
#   '判斷',
#   '不實',
#   '鑑價',
#   '投資前',
#   '之揚',
#   '報表',
#   '問題',
#   '銀行',
#   '億餘元',
#   '適法',
#   '有價',
#   '何以',
#   '情形',
#   '指摘',
#   '法院',
#   '第一百七',
#   '七千',
#   '法官',
#   '出示',
#   '九十一',
#   '上述',
#   '支付',
#   '行使',
#   '不法',
#   '依據',
#   '賣詐',
#   '欺罪',
#   '所辯',
#   '價值',
#   '下稱',
#   '評估',
#   '報告',
#   '風險',
#   '契約',
#   '產銷售',
#   '階段',
#   '連淑霞',
#   '有利於',
#   '憲誤',
#   '原審',
#   '採證',
#   '認事',
#   '職權',
#   '相關',
#   '事項',
#   '簽發',
#   '對價',
#   '敘明',
#   '預測',
#   '詐術',
#   '本件',
#   '決已',
#   '價證券',
#   '當事人',
#   '聲請',
#   '證事實',
#   '前述',
#   '九千',
#   '第二十',
#   '泛美',
#   '募集',
#   '九十',
#   '八千',
#   '法律',
#   '八十八年',
#   '二千',
#   '合作',
#   '之前',
#   '所指',
#   '八十七',
#   '交易',
#   '不合',
#   '一月',
#   '三十',
#   '文賢',
#   '審判決',
#   '違背',
#   '並非',
#   '具體',
#   '適用',
#   '實欄',
#   '欺行',
#   '撤銷',
#   '指駁',
#   '虛偽',
#   '資訊',
#   '發展',
#   '簽訂',
#   '契約書',
#   '約定',
#   '憲以',
#   '總價',
#   '一億',
#   '價格',
#   '購入',
#   '國際',
#   '萬股',
#   '股權',
#   '上開',
#   '所載',
#   '該化油'],
#  ['鑑定',
#   'EUPA',
#   '吳燦坤',
#   '掛牌',
#   '公司',
#   '檢察官',
#   '上訴',
#   '意見',
#   '永生',
#   '燦坤',
#   '美國',
#   '原判',
#   '證券',
#   'NASDAQ',
#   '被告',
#   '美國燦坤',
#   '記者',
#   '理由',
#   '10',
#   '美元',
#   '選任',
#   '資料',
#   '市場',
#   '法院',
#   '意旨',
#   '邱吉源',
#   '下稱',
#   '本件',
#   'OTCBB',
#   '說明',
#   '張震極',
#   '資產',
#   '市值',
#   '部分',
#   '公司股票',
#   '判決',
#   '訴訟法',
#   '並未',
#   '規定',
#   '原審',
#   '營收',
#   '刑事',
#   '交易',
#   '違法',
#   '經營',
#   '240',
#   '投資',
#   '投資人',
#   '條第',
#   '專家',
#   '本案',
#   '上市',
#   '違反',
#   '無罪',
#   '90',
#   '所為',
#   '證據',
#   '經驗',
#   '任武',
#   '內容',
#   '等語',
#   '不實',
#   '公開',
#   '相關',
#   '法官',
#   '交易法',
#   '人武',
#   '不得',
#   '第三',
#   '台灣',
#   '條規定',
#   '審上訴',
#   '負責人',
#   '15',
#   '22',
#   '劉建華',
#   '股價',
#   '證明',
#   '準備',
#   '審判長',
#   '不備',
#   '事項',
#   '專業',
#   '集團',
#   '推論',
#   '認定',
#   '罪刑',
#   '股份',
#   '每股',
#   '提出',
#   '指摘',
#   '辯護人',
#   '違背',
#   '燦寶',
#   '發展',
#   '財務',
#   'Inc',
#   '確定',
#   'ANC',
#   '發行',
#   '選擇權',
#   '證人',
#   '詞稿',
#   '分別',
#   '換股',
#   '造市',
#   '實績',
#   '誤述',
#   '開致',
#   '報價',
#   '情形',
#   '程序',
#   '有罪',
#   '所指',
#   '前述',
#   '斟酌',
#   '有限公司',
#   '案件',
#   '省略',
#   '股票',
#   '第一',
#   '律師',
#   '中華民國',
#   '審判決',
#   '決不',
#   '被訴',
#   '20',
#   '171',
#   '論處',
#   '依據',
#   '訴訟',
#   '公訴',
#   '協和證券',
#   '普海',
#   '開發',
#   'International',
#   '業經',
#   '非證',
#   '審判',
#   '泉富',
#   '期貨',
#   '辦理',
#   '000',
#   '增資',
#   '100',
#   '萬股',
#   '開記者',
#   '200',
#   '見原',
#   '審卷'],
#  ['財務',
#   '報告',
#   '原判',
#   '公司',
#   '重大',
#   '交易',
#   '鑑定',
#   '規定',
#   '認定',
#   '事項',
#   '本法',
#   '上訴',
#   '揭露',
#   '000',
#   '第一',
#   '影響',
#   '與關',
#   '第六',
#   '查核',
#   '交易法',
#   '判決',
#   '申報',
#   '下稱',
#   '投資人',
#   '第一百七',
#   '連續',
#   '記載',
#   '財報',
#   '人間',
#   '會計師',
#   '意見',
#   '證人',
#   '金額',
#   '理由',
#   '事實',
#   '隱匿',
#   '報表',
#   '計師',
#   '帳款',
#   '準則',
#   '階層',
#   '等語',
#   '會計',
#   '餘額',
#   '年度',
#   '修正',
#   '第二',
#   '是否',
#   '第十三',
#   '行人',
#   '刑事',
#   '公告',
#   '要件',
#   '第三',
#   '郭麗美',
#   '證據',
#   '負責人',
#   '發布',
#   '虛偽',
#   '公報',
#   '財務報',
#   '特別',
#   '決定',
#   '表達',
#   '資訊',
#   '第一款',
#   '證券',
#   '負有',
#   '經營',
#   '事務',
#   '應收',
#   '明確',
#   '違誤',
#   '資料',
#   '調查',
#   '訴訟法',
#   '知識',
#   '經驗',
#   '之證據',
#   '訂定',
#   '性標準',
#   '處罰',
#   '共同',
#   '期末',
#   '第四',
#   '背面',
#   '法官',
#   '十二年',
#   '十一月',
#   '三家',
#   '公允',
#   '犯罪',
#   '選任',
#   '慶豐',
#   '台灣',
#   '撤銷',
#   '發回',
#   '郭麗美有',
#   '犯證券',
#   '不實',
#   '判斷',
#   '適用',
#   '依據',
#   '有關',
#   '之事實',
#   '說明',
#   '犯意',
#   '明其',
#   '項規定',
#   '分別',
#   '行為',
#   '金管會',
#   '00000000',
#   '00',
#   '上開',
#   '之關',
#   '發生',
#   '應付',
#   '違反',
#   '財務會計',
#   '結果',
#   '查卷',
#   '具結',
#   '審前',
#   '理論',
#   '為何',
#   '應該',
#   '未揭露',
#   '誤解',
#   '一個',
#   '見原',
#   '輸送',
#   '不實罪',
#   '應依',
#   '十一',
#   '第七',
#   '本院',
#   '管理',
#   '印文',
#   '情事',
#   '法定',
#   '九十',
#   '三十日',
#   '主管',
#   '十九',
#   '七日',
#   '程式',
#   '根究',
#   '法院',
#   '境外'],
#  ['上訴',
#   '理由',
#   '一卡',
#   '原判',
#   '判決',
#   '資料',
#   '認定',
#   '證據',
#   '事實',
#   '第三',
#   '違法',
#   '張名',
#   '同案',
#   '刑事',
#   '訴訟法',
#   '審上訴',
#   '職權',
#   '袁昌樺',
#   '相關',
#   '交易法',
#   '被告',
#   '法官',
#   '公司股票',
#   '犯罪',
#   '結果',
#   '犯行',
#   '偵審',
#   '判斷',
#   '所為',
#   '李建華',
#   '不實',
#   '適法',
#   '鑑價',
#   '理法',
#   '指摘',
#   '不得',
#   '不知情',
#   '反證券',
#   '台灣',
#   '偵字',
#   '違背',
#   '法則',
#   '適用',
#   '價證券',
#   '有詐',
#   '欺行',
#   '敘明',
#   '調查',
#   '心證',
#   '可採',
#   '指駁',
#   '說明',
#   '之取',
#   '採證',
#   '認事',
#   '張瑋津',
#   '曹士剛',
#   '投資人',
#   '一卡公',
#   '證券',
#   '德三及',
#   '登記',
#   '證詞',
#   '實績',
#   '販售',
#   '銷售',
#   '申報',
#   '銷售額',
#   '經營',
#   '正犯',
#   '部分',
#   '公司',
#   '要件',
#   '年度',
#   '提供',
#   '程式',
#   '最高法院',
#   '所示',
#   '之行',
#   '所指',
#   '法律',
#   '台北',
#   '共同',
#   '十五',
#   '第一',
#   '法令',
#   '修正',
#   '行使',
#   '所得',
#   '九月',
#   '如何',
#   '十一',
#   '股票',
#   '五一六',
#   '法院',
#   '案件',
#   '予以',
#   '九十四年',
#   '三五七',
#   '第一百五十',
#   '第一百七',
#   '九十三',
#   '五八',
#   '明力',
#   '三百七十六',
#   '情形',
#   '程序',
#   '藉由',
#   '科刑',
#   '九十年',
#   '主文',
#   '因違',
#   '中華民國',
#   '審更',
#   '審判決',
#   '金上',
#   '起訴',
#   '案號',
#   '檢察署',
#   '九號',
#   '起上訴',
#   '條規定',
#   '非以判',
#   '決違',
#   '應以',
#   '書狀',
#   '並未',
#   '依據',
#   '內訴',
#   '具體',
#   '決不適',
#   '何種',
#   '不當',
#   '決違法',
#   '規定',
#   '適合時',
#   '認其',
#   '以駁',
#   '本件',
#   '原審',
#   '審理',
#   '杰有',
#   '事實欄',
#   '載違',
#   '明確',
#   '撤銷',
#   '審該',
#   '牽連犯',
#   '競合',
#   '犯關'],
#  ['證券',
#   '原判',
#   '上訴',
#   'Fund',
#   'LP',
#   '投資人',
#   '交易法',
#   'Lydia',
#   '判決',
#   '股權',
#   '理由',
#   '認定',
#   '投資信',
#   '姜克勤',
#   '檢察官',
#   '第三',
#   '公司',
#   '環球',
#   '第一',
#   '投資',
#   '問法',
#   '第一百七',
#   '資產',
#   '部分',
#   '另案',
#   '違法',
#   '發行',
#   '證據',
#   '蔡昌佑',
#   '組織',
#   '說明',
#   '規定',
#   '宏遠',
#   '企業',
#   '影響',
#   '刑事',
#   '被告',
#   '富裕',
#   '價證券',
#   '意旨',
#   '違背',
#   '小額',
#   '審判',
#   '無罪',
#   '審上訴',
#   '資料',
#   '適用',
#   '事實',
#   '一百零五',
#   '第二',
#   '違反',
#   '並非',
#   '契約型',
#   '判斷',
#   '十五',
#   '訴訟法',
#   '證明',
#   '架構',
#   '非法',
#   '法院',
#   '陳則',
#   '結果',
#   '同法',
#   '事項',
#   '不備',
#   '虛偽',
#   '集團',
#   '系爭',
#   '境外',
#   '募集',
#   '管理',
#   '基金',
#   '李佩芝',
#   '下稱',
#   '101',
#   '等語',
#   '並未',
#   '商行',
#   '提起',
#   '第一款',
#   '不得',
#   '指摘',
#   '之上',
#   '駁回',
#   '審理',
#   '不實',
#   '之關',
#   '股東會',
#   '相關',
#   '實體',
#   '罪嫌',
#   '供述',
#   '案件',
#   '三人',
#   '共同',
#   '合法',
#   '所示',
#   '是否',
#   '何以',
#   '法令',
#   '具體',
#   '原審',
#   '實欄',
#   '買賣',
#   '犯行',
#   '前證券',
#   '經營',
#   '認書',
#   '決認定',
#   '金管會',
#   '94',
#   '記載',
#   '徐楓',
#   '所為',
#   '誤信',
#   '我國',
#   '維持',
#   '沒有',
#   '妥速',
#   '公訴',
#   '修正',
#   '重大',
#   '予以',
#   '第五',
#   '第六款',
#   '三百七十六',
#   '情形',
#   '犯罪',
#   '要件',
#   '判例',
#   '瑕疵',
#   '台灣',
#   '選任',
#   '辯護人',
#   '起訴',
#   '訴訟',
#   '法則',
#   '有虛偽',
#   '同時',
#   '價證券罪',
#   '責任',
#   '予該',
#   '申購',
#   '由宏遠',
#   '銷售',
#   '規範',
#   '則不當',
#   '任職',
#   '開過',
#   '職權'],
#  ['林國仁',
#   '珍通',
#   '上訴',
#   '呂德茂',
#   '原判',
#   '許金村',
#   '調查',
#   '認定',
#   '證據',
#   '適用',
#   '被告',
#   '股票',
#   '判決',
#   '許兩旺',
#   '公司',
#   '確定',
#   '非常',
#   '法令',
#   '第一',
#   '參觀',
#   '事實',
#   '九十四年',
#   '刑事',
#   '違背',
#   '他們',
#   '不實',
#   '偵字',
#   '資料',
#   '八千',
#   '淑珍',
#   '檢察署',
#   '證券',
#   '台灣',
#   '六號',
#   '違法',
#   '投資人',
#   '許林秀卿',
#   '買賣',
#   '範圍',
#   '訴訟法',
#   '錯誤',
#   '違誤',
#   '實及',
#   '犯罪',
#   '附表',
#   '交易法',
#   '指摘',
#   '第四',
#   '意旨',
#   '未予',
#   '法官',
#   '侵占',
#   '九十三',
#   '年度',
#   '起訴',
#   '認為',
#   '告訴',
#   '證人',
#   '證稱',
#   '耐斯',
#   '犯意',
#   '聯絡',
#   '四十元',
#   '專利',
#   '介紹',
#   '證券詐',
#   '基礎',
#   '評價',
#   '以統',
#   '本旨',
#   '審判期',
#   '客觀',
#   '原審',
#   '部分',
#   '本院',
#   '地方法院',
#   '理由',
#   '卷宗',
#   '公司股票',
#   '最高法院',
#   '案件',
#   '金村',
#   '不合',
#   '第六',
#   '交還予',
#   '業經',
#   '桃園',
#   '處分',
#   '呂德茂介紹',
#   '無關',
#   '轉讓',
#   '登記',
#   '四編號',
#   '損害',
#   '之證',
#   '券詐',
#   '事項',
#   '內容',
#   '詐術',
#   '犯行',
#   '證明',
#   '一三二號',
#   '買十張',
#   '呂德茂買',
#   '蕭智仁',
#   '認識',
#   '沒有',
#   '完畢',
#   '當時',
#   '剛好',
#   '由林國仁',
#   '遠景',
#   '五號',
#   '決所',
#   '透過',
#   '股款',
#   '法則',
#   '糾正',
#   '項定',
#   '實為',
#   '之判',
#   '斷持',
#   '證據取',
#   '當否',
#   '即屬',
#   '規定',
#   '發行',
#   '行為',
#   '欺罔',
#   '下稱',
#   '詳如',
#   '分別',
#   '予許',
#   '一罪關',
#   '不屬',
#   '本件',
#   '裁量',
#   '四月',
#   '同案',
#   '法律',
#   '司法院',
#   '四十三',
#   '明文',
#   '法院',
#   '二嫂',
#   '自得',
#   '之事',
#   '其妻',
#   '同一',
#   '第一款'],
#  ['上訴',
#   '證據',
#   '原判',
#   '違法',
#   '調查',
#   '理由',
#   '判決',
#   '公司',
#   '意旨',
#   '認定',
#   '原審',
#   '第三',
#   '法院',
#   '審上訴',
#   '實際',
#   '事實',
#   '審判期',
#   '審判',
#   '指摘',
#   '用法',
#   '刑法',
#   '規定',
#   '89',
#   '資金',
#   '募資',
#   '職權',
#   '云云',
#   '另案',
#   '刑事',
#   '部分',
#   '訴訟法',
#   '並未',
#   '月間',
#   '股款',
#   '增資',
#   '犯行',
#   '條第',
#   '股東',
#   '賴奐辰',
#   '設立',
#   '傳聞',
#   '辯護',
#   '負責人',
#   '審酌',
#   '合法',
#   '法官',
#   '不得',
#   '共同',
#   '選任',
#   '辯護人',
#   '資料',
#   '法則',
#   '適用',
#   '明會',
#   '畫書',
#   '說明',
#   '擔任',
#   '則不當',
#   '訴人',
#   '159',
#   '作為',
#   '基礎',
#   '實審',
#   '指為',
#   '登記',
#   '第一',
#   '金主',
#   '程序',
#   '特定',
#   '明力',
#   '任意',
#   '本案',
#   '科刑',
#   '台灣',
#   '違背',
#   '依據',
#   '不當',
#   '三審',
#   '駁回',
#   '確定',
#   '違反',
#   '應收',
#   '審之',
#   '10',
#   '地區',
#   '心證',
#   '證言',
#   '名冊',
#   '並非',
#   '發起',
#   '採納',
#   '採證',
#   '57',
#   '日踐行',
#   '檢舉',
#   '則之',
#   '與賴',
#   '敘明',
#   '所為',
#   '決已',
#   '爭執',
#   '自非',
#   '適法',
#   '罪刑',
#   '正犯',
#   '各款',
#   '之上',
#   '情形',
#   '募集',
#   '要件',
#   '修正',
#   '能力',
#   '重罪',
#   '事宜',
#   '法律',
#   '交易法',
#   '予以',
#   '掌控',
#   '有罪',
#   '年度',
#   '被告',
#   '背面',
#   '張伊',
#   '決不適',
#   '本件',
#   '審理',
#   '結果',
#   '認上訴',
#   '102',
#   '犯意',
#   '證券交',
#   '登載',
#   '不實',
#   '詐取',
#   '財物',
#   '明確',
#   '55',
#   '偽罪',
#   '26',
#   '發布',
#   '通緝',
#   '繳納罪',
#   '原發',
#   '起人',
#   '明及',
#   '顧問',
#   '營運計',
#   '乃原',
#   '有利於',
#   '傳喚吳'],
#  ['上訴',
#   '規定',
#   '原判',
#   '交易法',
#   '保證',
#   '虛偽',
#   '證券',
#   '記載',
#   '背書',
#   '瑩寶',
#   '財務',
#   '報告',
#   '第三',
#   '行為',
#   '隱匿',
#   '法律',
#   '第一',
#   '修正',
#   '公司',
#   '第二',
#   '附表',
#   '一百七十四',
#   '適用',
#   '違反',
#   '申報',
#   '四月',
#   '第一百七',
#   '刑事',
#   '三十日',
#   '理由',
#   '文件',
#   '董事',
#   '判決',
#   '違法',
#   '處罰',
#   '相關',
#   '八十九年',
#   '罪刑',
#   '行使',
#   '第二十',
#   '情事',
#   '指摘',
#   '法官',
#   '本法',
#   '十三年',
#   '第五款',
#   '九十年',
#   '犯罪',
#   '條規定',
#   '審上訴',
#   '事錄',
#   '論處',
#   '證據',
#   '事實',
#   '機關',
#   '關業務',
#   '發行',
#   '責任',
#   '財務業務',
#   '上櫃',
#   '上開',
#   '刑法',
#   '行人',
#   '背信',
#   '公布',
#   '意旨',
#   '八十八年',
#   '公告',
#   '增列',
#   '情形',
#   '唐濟群',
#   '反證券',
#   '台灣',
#   '訴訟法',
#   '決違',
#   '違背',
#   '資料',
#   '具體',
#   '法則',
#   '結果',
#   '所載',
#   '偽造並',
#   '會會',
#   '議議',
#   '業務上',
#   '實文書',
#   '連續',
#   '新舊',
#   '應否',
#   '項比',
#   '舊法',
#   '增訂',
#   '賠償',
#   '之責任',
#   '價證券',
#   '及將',
#   '資訊',
#   '不實',
#   '事項',
#   '項之處',
#   '財務報',
#   '總經理',
#   '公開',
#   '各該',
#   '債務餘額',
#   '說明',
#   '私文書',
#   '吳英修',
#   '判斷',
#   '辦法',
#   '指為',
#   '法令',
#   '第五',
#   '部分',
#   '十一',
#   '明文',
#   '二十八日',
#   '不相',
#   '非金融',
#   '之上',
#   '年度',
#   '程式',
#   '最高法院',
#   '用法',
#   '前述',
#   '有如',
#   '一月',
#   '重大',
#   '一所',
#   '法定',
#   '六月',
#   '揭露',
#   '七月',
#   '任意',
#   '合法',
#   '主管',
#   '依法',
#   '提起',
#   '法院',
#   '予以',
#   '股份有限',
#   '第五十七',
#   '明力',
#   '程序',
#   '九十一',
#   '文定',
#   '科刑',
#   '主文',
#   '選任',
#   '辯護人'],
#  ['上訴',
#   '證券',
#   '原判',
#   '判決',
#   '環球',
#   '投資',
#   '起訴',
#   '交易法',
#   '理由',
#   '公司',
#   '企業',
#   '事實',
#   '富裕',
#   '判斷',
#   '商行',
#   '第一百七',
#   '刑事',
#   '第三',
#   '訴訟法',
#   '違背',
#   '集團',
#   '認定',
#   '宏遠',
#   'CFS',
#   '第一',
#   '法官',
#   '犯罪',
#   '法則',
#   '違法',
#   '股權',
#   '系爭',
#   '投資標',
#   '說明',
#   '證據',
#   '之事實',
#   '調查',
#   '結果',
#   '影響',
#   '檢察官',
#   '項之罪',
#   '指摘',
#   '非法',
#   '法院',
#   '年度',
#   '第八',
#   '科刑',
#   '十五',
#   '蔡昌佑',
#   '台灣',
#   '偵字',
#   '審上訴',
#   '並未',
#   '資料',
#   '適用',
#   '規定',
#   '之詐',
#   'LP',
#   '下稱',
#   '非屬',
#   '有價',
#   '顧問',
#   '指駁',
#   '甚詳',
#   '職權',
#   '經驗',
#   '指為',
#   '姜克勤',
#   '論述',
#   '採證',
#   '認事',
#   '論斷',
#   '宏遠公',
#   '下關',
#   '擔任',
#   '投資信',
#   '問法',
#   '審判',
#   '違反',
#   '審審理',
#   '原審',
#   '經營',
#   '證券業務及',
#   '九十七',
#   '理法',
#   '法律',
#   '行使',
#   '十一',
#   '七十五',
#   '董事',
#   '提起',
#   '有限公司',
#   '境外',
#   '意旨',
#   '要件',
#   '更正',
#   '程式',
#   '最高法院',
#   '八一',
#   '想像',
#   '不服',
#   '招募',
#   '法定',
#   '法令',
#   '前身',
#   '任意',
#   '第五',
#   '股份',
#   '彼此',
#   '私募',
#   '予以',
#   '部分',
#   '第一二',
#   '同一',
#   '明力',
#   '情形',
#   '程序',
#   '九六',
#   '免刑',
#   '募集',
#   '主文',
#   '金融管理',
#   '基金',
#   '五號',
#   '選任',
#   '辯護人',
#   '柏有',
#   '為律師',
#   '張峪嘉律師',
#   '林志忠律師',
#   '因違',
#   '反證券',
#   '中華民國',
#   '審更',
#   '審判決',
#   '金上',
#   '案號',
#   '檢察署',
#   '條規定',
#   '非以判',
#   '決違',
#   '應以',
#   '書狀',
#   '依據',
#   '內訴',
#   '具體',
#   '決不適',
#   '何種',
#   '不當',
#   '決違法',
#   '適合時'],
#  ['上訴',
#   '蕃薯',
#   '上櫃',
#   '簡麗蓉',
#   '購買',
#   '附表',
#   '公司股票',
#   '公司',
#   '原判',
#   '侯銀月',
#   '簡妙蓉',
#   '十三年',
#   '九十三',
#   '第一',
#   '股票',
#   '六月',
#   '審卷',
#   '股東',
#   '所示',
#   '認定',
#   '獲利',
#   '申請',
#   '四十七',
#   '判決',
#   '價格',
#   '證券',
#   '影本',
#   '證人',
#   '簡煥期',
#   '一編號',
#   '審證',
#   '三十元',
#   '理由',
#   '十二年',
#   '違背',
#   '萬元',
#   '十五',
#   '每股',
#   '錯誤',
#   '虛偽',
#   '沒有',
#   '匯款',
#   '年度',
#   '二十五元',
#   '訴人',
#   '投資者',
#   '結婚',
#   '掛牌',
#   '警卷',
#   '華證券',
#   '輔導',
#   '狀況',
#   '九十',
#   '惠子',
#   '一所',
#   '指摘',
#   '上市',
#   '第三',
#   '規定',
#   '犯行',
#   '介紹',
#   '等語',
#   '擔任',
#   '負責人',
#   '執行長',
#   '親友',
#   '送件',
#   '董事',
#   '同年',
#   '法令',
#   '意旨',
#   '依據',
#   '資料',
#   '所載',
#   '鐘彬',
#   '並有',
#   '附卷',
#   '侯貴貞',
#   '簡攸蓉',
#   '因為',
#   '股價',
#   '見原',
#   '末永多',
#   '可證',
#   '之訊息',
#   '麗枝',
#   '股權',
#   '預期',
#   '原審',
#   '一月',
#   '告知',
#   '九十四年',
#   '三月',
#   '年初',
#   '云云',
#   '第二',
#   '十四日',
#   '台灣',
#   '法則',
#   '投資人',
#   '人頭',
#   '之人頭',
#   '認為',
#   '實欄',
#   '網公',
#   '雅菁',
#   '鐘逸芳',
#   '林琳曉',
#   '林珈',
#   '人購',
#   '虛偽訊息',
#   '統一證券',
#   '合計',
#   '契約',
#   '投資',
#   '幫忙',
#   '金額',
#   '即將',
#   '不實',
#   '張顯貴',
#   '判斷',
#   '審查',
#   '欺行',
#   '市場',
#   '十月',
#   '十二',
#   '中西',
#   '第五',
#   '交易法',
#   '法官',
#   '十二月',
#   '被害人',
#   '姊夫',
#   '七月',
#   '六二',
#   '九十一',
#   '二日',
#   '並未',
#   '違法',
#   '本件',
#   '電子',
#   '郵件',
#   '相關',
#   '預計',
#   '池浦泰宏',
#   '內容',
#   '無法',
#   '連續',
#   '當然',
#   '認識'],
#  ['志豪',
#   '原判',
#   '李仁魯',
#   '上訴',
#   '瑞傳',
#   '編號',
#   '公司',
#   '證據',
#   '寰生',
#   '調查',
#   '違法',
#   '理由',
#   '九十年',
#   '判決',
#   '認定',
#   '資料',
#   '交易法',
#   '檢察官',
#   '下稱',
#   '第一',
#   '八十九年',
#   '公司股票',
#   '台灣',
#   '報導',
#   '事實',
#   '轉廠',
#   '意旨',
#   '云云',
#   '第一百七',
#   '規定',
#   '原審',
#   '日報',
#   '證人',
#   '第三',
#   '部分',
#   '技術移',
#   '教授',
#   '證券',
#   '晚報',
#   '專利權',
#   '投資',
#   '建議',
#   '購買',
#   '證明',
#   '指摘',
#   '100',
#   '擁有',
#   '審審理',
#   '袁家瑋',
#   '第一款',
#   '違背',
#   '實欄',
#   'CCMP',
#   '內容',
#   '商開',
#   '畫書',
#   '藍芽',
#   '李世強',
#   '子郎',
#   '登記',
#   '判斷',
#   '決關',
#   '實訊息',
#   '修正',
#   '股票',
#   '刑事',
#   '犯罪',
#   '訴訟法',
#   '審上訴',
#   '法則',
#   '行為',
#   '記者',
#   '記載',
#   '商申',
#   '發計',
#   '楊佩芝',
#   '李鳳魯',
#   '偵查',
#   '股價',
#   '社會',
#   '投資大眾',
#   '設立',
#   '投資人',
#   'Enterprise',
#   '企業',
#   '西元',
#   '法妮',
#   '法院',
#   '共同',
#   '十一',
#   '附表',
#   '董事',
#   '茂盛',
#   '不得',
#   '違反',
#   '並未',
#   '本件',
#   '新聞報',
#   '計畫',
#   '請表',
#   '相關',
#   '股東',
#   '所為',
#   '顯有',
#   '不備',
#   '獲利',
#   '林來',
#   '白川珍',
#   '李勝仁',
#   '李國銘',
#   '之事實',
#   '萬股',
#   '王冰清',
#   '職權',
#   '簽訂',
#   '透過',
#   '等語',
#   '影本',
#   '之證據',
#   '審判',
#   'Franices',
#   'Bio',
#   'Tech',
#   '法妮詩',
#   '簽約',
#   '七十七',
#   '十九日',
#   '提出',
#   '高雄',
#   '百分之十',
#   '第二十',
#   '七月',
#   '三月',
#   '八月',
#   '六日',
#   '新加坡',
#   '持有',
#   '科刑',
#   '主文',
#   '李仁',
#   '起訴',
#   '依據',
#   '適用',
#   '結果',
#   '認為',
#   '犯行',
#   '撤銷',
#   '有利於',
#   '略稱',
#   '聯合報'],
#  ['上訴',
#   '起訴',
#   '證券',
#   '原判',
#   '判決',
#   '第三',
#   '審上訴',
#   '結果',
#   '證據',
#   '判斷',
#   '市場',
#   '理由',
#   '部分',
#   '提起',
#   '規定',
#   '違法',
#   '違反',
#   '事實',
#   '已經',
#   '自訴',
#   '未經',
#   '偵查',
#   '投資人',
#   '聯想',
#   '公司',
#   '交易法',
#   '第一',
#   '法官',
#   '一部',
#   '台灣台',
#   '認為',
#   '確定',
#   '告訴',
#   '下稱',
#   '經營績',
#   '投資',
#   '高標',
#   '刑事',
#   '地方法院',
#   '九十九',
#   '意旨',
#   '犯罪',
#   '法律',
#   '另案',
#   '裁判',
#   '九十四年',
#   '第一百七',
#   '年度',
#   '全部',
#   '九四',
#   '李良奇',
#   '檢察署',
#   '二一號',
#   '訴訟法',
#   '違背',
#   '資料',
#   '法則',
#   '適用',
#   '以駁',
#   '審理',
#   '論處',
#   '有價',
#   '欺行',
#   '調查',
#   '認定',
#   '公訴',
#   '審判',
#   '分之關',
#   '雖經',
#   '檢察官',
#   '仍得',
#   '處分',
#   '說明',
#   '紀淑芬',
#   '實體',
#   '違誤',
#   '為維護',
#   '發生',
#   '發展',
#   '認聯想',
#   '光電',
#   '投資評',
#   '估書',
#   '雜誌',
#   '明會',
#   '價格',
#   '錯誤',
#   '銷售',
#   '授權',
#   '同法',
#   '不得',
#   '其他',
#   '第二十',
#   '指摘',
#   '法院',
#   '不相',
#   '要件',
#   '被害人',
#   '明人',
#   '程式',
#   '最高法院',
#   '本案',
#   '再行',
#   '科技股份',
#   '科技',
#   '第二',
#   '不可',
#   '十五',
#   '散布',
#   '效力',
#   '有限公司',
#   '十二',
#   '法令',
#   '健全',
#   '交易',
#   '十一',
#   '之事',
#   '之上',
#   '明力',
#   '情形',
#   '取巧',
#   '科刑',
#   '二四',
#   '主文',
#   '選任',
#   '辯護人',
#   '姜志俊律師',
#   '因違',
#   '反證券',
#   '台灣',
#   '中華民國',
#   '審更',
#   '審判決',
#   '案號',
#   '偵字',
#   '條規定',
#   '非以判',
#   '決違',
#   '應以',
#   '書狀',
#   '並未',
#   '依據',
#   '內訴',
#   '具體',
#   '決不適',
#   '何種',
#   '不當',
#   '決違法',
#   '適合時',
#   '認其'],
#  ['一卡',
#   '上訴',
#   '證券',
#   '原判',
#   '價證券',
#   '適用',
#   '規定',
#   '第一百七',
#   '理由',
#   '交易法',
#   '認定',
#   '行為',
#   '不實',
#   '第一',
#   '說明',
#   '公司股票',
#   '犯罪',
#   '公司',
#   '判決',
#   '實欄',
#   '依據',
#   '記載',
#   '發行',
#   '下稱',
#   '資料',
#   '萬元',
#   '購買',
#   '投資',
#   '判斷',
#   '違反',
#   '犯行',
#   '有價',
#   '欺行',
#   '事實',
#   '欺罔',
#   '技術',
#   '投資人',
#   '億元',
#   '雜誌',
#   '訴人',
#   '證券詐',
#   '報刊',
#   '證據',
#   '十一',
#   '第一款',
#   '不得',
#   '十一年',
#   '第六款',
#   '撤銷',
#   '有詐',
#   '欺罪',
#   '鑑價',
#   '記者',
#   '資訊',
#   '錯誤',
#   '李王良',
#   '詐術',
#   '市場',
#   '廣播',
#   '電影',
#   '文書',
#   '股票',
#   '方法',
#   '修正',
#   '共同',
#   '所得',
#   '刑事',
#   '第二十',
#   '九十九',
#   '部分',
#   '法官',
#   '一百七十四',
#   '募集',
#   '科刑',
#   '台灣',
#   '起訴',
#   '發回',
#   '事實欄',
#   '誤信',
#   '騙取',
#   '財物',
#   '自應',
#   '輔導',
#   '工研院',
#   '範圍',
#   '日報',
#   '張瑋津',
#   '論處',
#   '適法',
#   '特別',
#   '予陳功源',
#   '結果',
#   '發生',
#   '罰金',
#   '原則',
#   '九十七',
#   '之行',
#   '第三十',
#   '交易',
#   '私募',
#   '法律',
#   '有期徒刑',
#   '第二',
#   '第八',
#   '本院',
#   '刑法',
#   '不知情',
#   '施用',
#   '二千',
#   '他人',
#   '不法',
#   '以上',
#   '有限公司',
#   '以下',
#   '第四段',
#   '第三',
#   '選任',
#   '辯護人',
#   '偵字',
#   '所載',
#   '之判',
#   '競合犯',
#   '連續',
#   '敘及',
#   '之證券詐',
#   '處罰',
#   '足致',
#   '指行',
#   '圖為',
#   '實際',
#   '鈴木旭',
#   '客戶',
#   '訂單',
#   '犯意',
#   '聯絡',
#   '財務',
#   '預測',
#   '翻譯',
#   '總計',
#   '台幣',
#   '分別',
#   '德信',
#   '簽訂',
#   '契約',
#   '上櫃',
#   '計畫',
#   '防偽',
#   '十點',
#   '經濟',
#   '袁昌樺'],
#  ['原判',
#   '公司',
#   'CCMP',
#   '100',
#   '證據',
#   '九十年',
#   '說明',
#   '藍芽',
#   '理由',
#   '上訴',
#   '事實',
#   '研發',
#   '寰生',
#   '專利權',
#   '等語',
#   '台灣',
#   '下稱',
#   '李世強',
#   '計畫',
#   '情況',
#   '抗癌',
#   '實欄',
#   '證券',
#   '證明',
#   '認定',
#   '國內',
#   '藥物',
#   '美國',
#   '之特別',
#   '教授',
#   '高雄',
#   '交易法',
#   '可信',
#   '第一百七',
#   '刑事',
#   '犯罪',
#   '判決',
#   '依據',
#   '市場',
#   '八十九年',
#   '總經理',
#   '醫學大學',
#   '衛生署',
#   '專利',
#   '記者',
#   '上櫃',
#   '調查',
#   '訴訟法',
#   '原則',
#   '晚報',
#   '第一',
#   '法官',
#   '不得',
#   '公司股票',
#   '九十八',
#   '撤銷',
#   '發回',
#   '記載',
#   '發行',
#   '價證券',
#   '有詐',
#   '擔任',
#   '負責人',
#   '郭國華',
#   '治療',
#   '中草藥',
#   '獲得',
#   '發明',
#   '草藥',
#   '龍葵',
#   '醫藥委員會',
#   '犯意',
#   '作為',
#   '投資大眾',
#   '營業',
#   '臨床',
#   '實驗',
#   '細胞',
#   '規定',
#   '審判',
#   '九條',
#   '證人',
#   '面陳述',
#   '日報',
#   '報社',
#   '十一',
#   '有期徒刑',
#   '共同',
#   '明文',
#   '成功',
#   '研究',
#   '能力',
#   '第一款',
#   '五日',
#   '部分',
#   '第一百五十',
#   '癌症',
#   '年度',
#   '明知',
#   '科刑',
#   '一月',
#   '司法警察',
#   '選任',
#   '辯護人',
#   '經營',
#   '無罪',
#   '敘明',
#   '有價',
#   '誤信',
#   '特別',
#   '楊玉莉',
#   '進行',
#   '簽訂',
#   '合開',
#   '學術界',
#   '分離',
#   '以研',
#   '發中',
#   '應用',
#   '內容',
#   '投資',
#   '建議',
#   '預計',
#   '申請',
#   '掛牌',
#   '並非',
#   '移轉',
#   '醫藥',
#   '技術移',
#   '轉廠',
#   '畫書',
#   '未來',
#   '生公',
#   '銷售',
#   '聯絡',
#   '剪報',
#   '資料',
#   '明會',
#   '媒體',
#   '提煉',
#   '藥品',
#   '簽約',
#   '召開',
#   '誤導',
#   '報告',
#   '之規定',
#   '決就',
#   '適用',
#   '依上',
#   '適法']]

# %%
flat = [x for sublist in subdata_seg_list for x in sublist]
diction = Counter(flat)

# %%
from PIL import Image
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
mask = np.array(Image.open("criminal.jpg"))
font = "C:\Windows\Fonts\MSJH.TTC"

# %%
wordcloud = WordCloud(background_color = "white", font_path=font, mask = mask)
wordcloud.generate_from_frequencies(diction)

# %%
plt.figure(figsize=(20,20))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
