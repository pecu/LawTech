# %% [markdown]
# # 課堂講解&作業題目
#
# ### 題目一：
#
# 已知有甲、乙、丙三人，分別分別年齡為40、52、63，他們分別觸犯多條道路交通管理處罰條例。
#
# 甲：第62條 汽車駕駛人駕駛汽車肇事，被罰了2000元、
#     第12條 汽車使用吊銷、註銷之牌照，被罰了5000元
#
# 乙：第16條 裝置高音量喇叭或其他產生噪音器物，被罰了1200元、
#     第56條 在禁止臨時停車處所停車，被罰了800元、
#     第82條 未經許可在道路擺設攤位，被罰了1500元、
#     第17條 汽車不依限期參加定期檢驗或臨時檢驗，被罰了900元
#
# 丙：第21條 未領有駕駛執照駕駛小型車或機車，被罰了8000元
#
# 請使用while迴圈讓使用者選擇：
# 1.查看甲資料    2.查看乙資料    3.查看丙資料    4.犯罪數排名    5.累積罰金&罰鍰數排名    6.結束程式
#
# 其餘(包含文字)顯示請重新輸入

# %%
print('觸犯道路交通管理處罰條例人員名單')
A = {'name':'甲','age':40,'罪責':{'第62條':'汽車駕駛人駕駛汽車肇事','第12條':'汽車使用吊銷、註銷之牌照'},
                            '罰鍰':{'第62條':2000,'第12條':5000}}

B = {'name':'乙','age':52,'罪責':{'第16條':'裝置高音量喇叭或其他產生噪音器物','第56條':'在禁止臨時停車處所停車',
                                   '第82條':'未經許可在道路擺設攤位','第17條':'汽車不依限期參加定期檢驗或臨時檢驗'},
                            '罰鍰':{'第16條':1200,'第56條':800,'第82條':1500,'第17條':900}}

C = {'name':'丙','age':63,'罪責':{'第21條':'未領有駕駛執照駕駛小型車或機車'},'罰鍰':{'第21條':8000}}

def guilt(name): #定義guilt()函數，計算罪責數和處存罪責內容
    a = len(name['罪責']) 
    n = []
    for b in name['罪責']: #for gu in name['罪責'].items():
        gu = (b,name['罪責'][b]) 
        n.append(gu)
    return a, n

def money(name): #定義money()函數，計算總金額和處存罰鍰內容
    m = 0
    n = []
    for c in name['罰鍰']: #for mg, moo in name['罰鍰'].items():
        mo = (c,name['罰鍰'][c]) #mo = (mg, moo)
        n.append(mo) 
        m += name['罰鍰'][c] #m += moo
    return m, n

'''犯罪次數排名'''
gua, ga = guilt(A) #宣告讀取函數回傳值 (罪責數, 罪責內容)
gub, gb = guilt(B)
guc, gc = guilt(C)
x = [gua,gub,guc]
#設定原始位置 
x1 = enumerate(x, start = 1) #print(x1) >>>[(1,gua),(2,gub),(3,guc)]
#進行排名
x2 = sorted(x1, key = lambda s: s[1]) #sorted(reverse = False)由小到大 

#l = lambda s: s[1]
#x2 = sorted(x1, key = l)


'''罰錢金額排名'''
moa, ma = money(A) #宣告讀取函數回傳值 (金額總數, 對應罪責)
mob, mb = money(B)
moc, mc = money(C)
y = [moa,mob,moc]
y1 = enumerate(y, start = 1) #設定原始位置
y2 = sorted(y1, key = lambda s: s[1]) #進行排名

def getit(name): #定義getit()函數執行for-loop
    for i in name:
        print(i)

while True: #開始題目要求之迴圈
    options = input('請輸入: 1.查看甲 2.查看乙 3.查看丙 4.犯罪數排名 5.累積罰金&罰鍰數排名 6.結束程式:')
    if options == '1':
        print('Name:',A['name'],'\nAge:',A['age']) #\n分行
        print('共觸犯(條):',gua)
        print('條例內容:')
        getit(ga) #呼叫函數
        print('罰鍰總額(元):',moa)
        print('詳細內容:')
        getit(ma)
    elif options == '2':
        print('Name:',B['name'],'\nAge:',B['age'])
        print('共觸犯(條):',gub)
        print('條例內容:')
        getit(gb)
        print('罰鍰總額(元):',mob)
        print('詳細內容:')
        getit(mb)
    elif options == '3':
        print('Name:',C['name'],'\nAge:',C['age'])
        print('共觸犯(條):',guc)
        print('條例內容:')
        getit(gc)
        print('罰鍰總額(元):',moc)
        print('詳細內容:')
        getit(mc)
    elif options == '4':
        print('甲為1，乙為2，丙為3')
        print('(人,犯罪次數)(少->多）')
        print(x2)
    elif options == '5':
        print('甲為1，乙為2，丙為3')
        print('(人,金額)(少->多）')
        print(y2)
    elif options == '6':
        print('Bye bye~~~')
        break
    else:
        print('輸入錯誤，請重新輸入')
        continue


# 道路交通管理處罰條例62條 汽車駕駛人駕駛汽車肇事 新臺幣一千元以上三千元以下罰鍰
# 道路交通管理處罰條例12條 汽車使用吊銷、註銷之牌照 新臺幣三千六百元以上一萬零八百元以下罰鍰
# 道路交通管理處罰條例16條 裝置高音量喇叭或其他產生噪音器物 新臺幣九百元以上一千八百元以下罰鍰
# 道路交通管理處罰條例56條 在禁止臨時停車處所停車 新臺幣六百元以上一千二百元以下罰鍰
# 道路交通管理處罰條例82條 未經許可在道路擺設攤位 新臺幣一千二百元以上二千四百元以下罰鍰
# 道路交通管理處罰條例17條 汽車不依限期參加定期檢驗或臨時檢驗 新臺幣九百元以上一千八百元以下罰鍰
# 道路交通管理處罰條例21條 未領有駕駛執照駕駛小型車或機車 新臺幣六千元以上一萬二千元以下罰鍰
# Out:
# 觸犯道路交通管理處罰條例人員名單
# 請輸入: 1.查看甲 2.查看乙 3.查看丙 4.犯罪數排名 5.累積罰金&罰鍰數排名 6.結束程式:1
# Name: 甲
# Age: 40
# 共觸犯(條): 2
# 條例內容:
# ('第62條', '汽車駕駛人駕駛汽車肇事')
# ('第12條', '汽車使用吊銷、註銷之牌照')
# 罰鍰總額(元): 7000
# 詳細內容:
# ('第62條', 2000)
# ('第12條', 5000)
# 請輸入: 1.查看甲 2.查看乙 3.查看丙 4.犯罪數排名 5.累積罰金&罰鍰數排名 6.結束程式:2
# Name: 乙
# Age: 52
# 共觸犯(條): 4
# 條例內容:
# ('第16條', '裝置高音量喇叭或其他產生噪音器物')
# ('第56條', '在禁止臨時停車處所停車')
# ('第82條', '未經許可在道路擺設攤位')
# ('第17條', '汽車不依限期參加定期檢驗或臨時檢驗')
# 罰鍰總額(元): 4400
# 詳細內容:
# ('第16條', 1200)
# ('第56條', 800)
# ('第82條', 1500)
# ('第17條', 900)
# 請輸入: 1.查看甲 2.查看乙 3.查看丙 4.犯罪數排名 5.累積罰金&罰鍰數排名 6.結束程式:3
# Name: 丙
# Age: 63
# 共觸犯(條): 1
# 條例內容:
# ('第21條', '未領有駕駛執照駕駛小型車或機車')
# 罰鍰總額(元): 8000
# 詳細內容:
# ('第21條', 8000)
# 請輸入: 1.查看甲 2.查看乙 3.查看丙 4.犯罪數排名 5.累積罰金&罰鍰數排名 6.結束程式:4
# 甲為1，乙為2，丙為3
# (人,犯罪次數)(少->多）
# [(3, 1), (1, 2), (2, 4)]
# 請輸入: 1.查看甲 2.查看乙 3.查看丙 4.犯罪數排名 5.累積罰金&罰鍰數排名 6.結束程式:5
# 甲為1，乙為2，丙為3
# (人,金額)(少->多）
# [(2, 4400), (1, 7000), (3, 8000)]
# 請輸入: 1.查看甲 2.查看乙 3.查看丙 4.犯罪數排名 5.累積罰金&罰鍰數排名 6.結束程式:fge
# 輸入錯誤，請重新輸入
# ...

# %% [markdown]
# ### 練習(作業一) :
#
# 請仿照第一題：
#
# 已知有阿程、阿力、阿瑤三人，分別分別年齡為34、29、58，他們分別觸犯多條道路交通管理處罰條例。
#
# 甲：第16條 裝置高音量喇叭或其他產生噪音器物，被罰了1600元、
#           第17條 汽車不依限期參加定期檢驗或臨時檢驗，被罰了1500元、
#           第62條 汽車駕駛人駕駛汽車肇事，被罰了2500元、
#           第21條 未領有駕駛執照駕駛小型車或機車，被罰了10500元
#
# 乙：第12條 汽車使用吊銷、註銷之牌照，被罰了5000元
#
# 丙：第82條 未經許可在道路擺設攤位，被罰了2000元、
#           第56條 在禁止臨時停車處所停車，被罰了1000元
#
# 請使用while迴圈讓使用者選擇：
# 1.查看阿程資料    2.查看阿力資料    3.查看阿瑤資料    4.犯罪數排名
# 5.累積罰金&罰鍰數排名    6.結束程式
#
# 其餘(包含文字)顯示請重新輸入

# %% [raw]
# 執行結果:
# 觸犯道路交通管理處罰條例人員名單
# 請輸入: 1.查看阿程 2.查看阿力 3.查看阿瑤 4.犯罪數排名 5.累積罰金&罰鍰數排名 6.結束程式:1
# Name: 阿程
# Age: 34
# 共觸犯(條): 4
# 條例內容:
# ('第16條', '裝置高音量喇叭或其他產生噪音器物')
# ('第17條', '汽車不依限期參加定期檢驗或臨時檢驗')
# ('第62條', '汽車駕駛人駕駛汽車肇事')
# ('第21條', '未領有駕駛執照駕駛小型車或機車')
# 罰鍰總額(元): 16100
# 詳細內容:
# ('第16條', 1600)
# ('第17條', 1500)
# ('第62條', 2500)
# ('第21條', 10500)
# 請輸入: 1.查看阿程 2.查看阿力 3.查看阿瑤 4.犯罪數排名 5.累積罰金&罰鍰數排名 6.結束程式:2
# Name: 阿力
# Age: 29
# 共觸犯(條): 1
# 條例內容:
# ('第12條', '汽車使用吊銷、註銷之牌照')
# 罰鍰總額(元): 5000
# 詳細內容:
# ('第12條', 5000)
# 請輸入: 1.查看阿程 2.查看阿力 3.查看阿瑤 4.犯罪數排名 5.累積罰金&罰鍰數排名 6.結束程式:3
# Name: 阿瑤
# Age: 58
# 共觸犯(條): 2
# 條例內容:
# ('第82條', '未經許可在道路擺設攤位')
# ('第56條', '在禁止臨時停車處所停車')
# 罰鍰總額(元): 3000
# 詳細內容:
# ('第82條', 2000)
# ('第56條', 1000)
# 請輸入: 1.查看阿程 2.查看阿力 3.查看阿瑤 4.犯罪數排名 5.累積罰金&罰鍰數排名 6.結束程式:4
# 阿程為1，阿力為2，阿瑤為3
# (人,犯罪次數)(少->多）
# [(2, 1), (3, 2), (1, 4)]
# 請輸入: 1.查看阿程 2.查看阿力 3.查看阿瑤 4.犯罪數排名 5.累積罰金&罰鍰數排名 6.結束程式:5
# 阿程為1，阿力為2，阿瑤為3
# (人,金額)(少->多）
# [(3, 3000), (2, 5000), (1, 16100)]
# 請輸入: 1.查看阿程 2.查看阿力 3.查看阿瑤 4.犯罪數排名 5.累積罰金&罰鍰數排名 6.結束程式:d
# 輸入錯誤，請重新輸入
# 請輸入: 1.查看阿程 2.查看阿力 3.查看阿瑤 4.犯罪數排名 5.累積罰金&罰鍰數排名 6.結束程式:6
# Bye bye~~~

# %% [markdown]
# ### 作業二 :
#
# 嘟嘟想要了解親屬間的關係，試問：
#
# 1.姑媽與嘟嘟（自己）
#
# 2.祖父與外孫女
#
# 3.侄子與姨媽
#
# 4.哥哥與表姊妹
#
# 5.表兄弟與女兒
#
# 之間，在親屬圖上相隔哪幾位親屬？並計算兩者間的親等關係。
#
# 使用while-loop讓使用者輸入題號(羅馬數字)察看結果，按6結束，按其餘(包含文字)顯示請重新輸入。
#
# hint:
#
# 建立兩個list()
#
# for-loop取得索引，用作讀取內容和計算親等

# %% [raw]
# 執行結果:
# 親屬關係圖(親等計算)
# 輸入題號(羅馬數字)按6結束:1
# 姑媽與嘟嘟
# 旁系 3親等
# 姑媽
# 祖父
# 父親
# 自己
# 輸入題號(羅馬數字)按6結束:2
# 祖父與外孫女
# 直系 4親等
# 祖父
# 父親
# 自己
# 女兒
# 外孫女
# 輸入題號(羅馬數字)按6結束:3
# 侄子與姨媽
# 旁系 4親等
# 侄子
# 哥哥
# 母親
# 外祖父
# 姨媽
# 輸入題號(羅馬數字)按6結束:4
# 哥哥與表姊妹
# 旁系 4親等
# 哥哥
# 母親
# 外祖父
# 姨媽
# 表姊妹
# 輸入題號(羅馬數字)按6結束:5
# 表兄弟與女兒
# 旁系 5親等
# 表兄弟
# 姑媽
# 祖父
# 父親
# 自己
# 女兒
# 輸入題號(羅馬數字)按6結束:h
# 請重新輸入
# 輸入題號(羅馬數字)按6結束:6

# %% [markdown]
# ### 作業三 :
#
# 現有一篇法律判決
#
# 請使用while-loop讓使用者輸入
# 1.頁首 2.主文 3.原告主張 4.被告則以 5.事件背景 6.罰款 7.債權 8.原告請求 9.結果 10.結語 11.訴訟費用負擔之依據 12.頁尾 13.退出
# 其餘(包含文字)顯示請重新輸入
#
# hint : 以輸入內容為標題，建立dictionary(頁首、頁尾等)
#
# 罰款部分請儲存在相同的字典裡，並以dict和list儲存其問題和內容項目，以for迴圈分點呈現

# %% [raw]
# 執行結果:
# 108,訴,394 2019/10/18 損害賠償
# 請選擇欲查看之項目 1.頁首 2.主文 3.原告主張 4.被告則以 5.事件背景 6.罰款 7.債權 8.原告請求 9.結果 10.結語 11.訴訟費用負擔之依據 12.頁尾 13.退出:1
# 臺灣臺北地方法院民事判決 108年度訴字第394號
# 原告 李曼甄	李坤翰
# 訴訟代理人 陳為元律師
# 被告 張慎如
# 請選擇欲查看之項目 1.頁首 2.主文 3.原告主張 4.被告則以 5.事件背景 6.罰款 7.債權 8.原告請求 9.結果 10.結語 11.訴訟費用負擔之依據 12.頁尾 13.退出:2
# 主文：
# 被告應給付原告李曼甄新臺幣貳拾玖萬肆仟捌佰貳拾捌元，及自民國一百零七年十二月二十日起至清償日止，按週年利率百分之五計算之利息。被告應給付原告李坤翰新臺幣參仟伍佰元，及自民國一百零八年一月三十一日起至清償日止，按週年利率百分之五計算之利息。原告其餘之訴駁回。訴訟費用由被告負擔百分之二十一，餘由原告負擔。本判決第一項得假執行，但被告如以新臺幣貳拾玖萬肆仟捌佰貳拾捌元為原告李曼甄預供擔保，得免為假執行。本判決第二項得假執行，但被告如以新臺幣參仟伍佰元為原告李坤翰預供擔保，得免為假執行。原告其餘假執行之聲請駁回。
# 請選擇欲查看之項目 1.頁首 2.主文 3.原告主張 4.被告則以 5.事件背景 6.罰款 7.債權 8.原告請求 9.結果 10.結語 11.訴訟費用負擔之依據 12.頁尾 13.退出:3
# 原告主張：
# 原告主張被告於民國106 年11月12日上午9 時42分許，駕駛車牌號碼00-0000號自用小客車（下稱系爭汽車），沿臺北市文山區木柵路2段由西往東方向內側車道行駛而欲左轉進入木柵路2段109巷口時，竟疏未注意轉彎車應讓直行車先行即貿然左轉，因而與沿臺北市文山區木柵路2段東往西方向由原告李曼甄（下稱李曼甄）所騎乘、原告李坤翰（稱李坤翰）所有之車牌號碼000-000 號普通重型機車（